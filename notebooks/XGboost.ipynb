# %%
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from xgboost.callback import EarlyStopping
import plotly.graph_objects as go

# %% [markdown]
# # ✅ Fonction pour supprimer toutes les colonnes finissant par _Open, _Low, _High

# %%
def drop_ohl_columns(df):
    cols_to_drop = [col for col in df.columns
                    if col.endswith(("_Open", "_Low", "_High"))]
    return df.drop(columns=cols_to_drop)

# %%
df = pd.read_csv(
    "Clean_Data.csv",
    sep=",",
    index_col="Date",
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3386 entries, 2012-01-26 to 2025-12-10
# Data columns (total 87 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   VIX_Open         3386 non-null   float64
#  1   VIX_High         3386 non-null   float64
#  2   VIX_Low          3386 non-null   float64
#  3   VIX_Close        3386 non-null   float64
#  4   DX-Y.NYB_Open    3386 non-null   float64
#  5   DX-Y.NYB_High    3386 non-null   float64
#  6   DX-Y.NYB_Low     3386 non-null   float64
#  7   DX-Y.NYB_Close   3386 non-null   float64
#  8   PA_F_Open        3386 non-null   float64
#  9   PA_F_High        3386 non-null   float64
#  10  PA_F_Low         3386 non-null   float64
#  11  PA_F_Close       3386 non-null   float64
#  12  BZ_F_Open        3386 non-null   float64
#  13  BZ_F_High        3386 non-null   float64
#  14  BZ_F_Low         3386 non-null   float64
#  15  BZ_F_Close       3386 non-null   float64
#  16  OVX_Open         3386 non-null   float64
#  17  OVX_High         3386 non-null   float64
#  18  OVX_Low          3386 non-null   float64
#  19  OVX_Close        3386 non-null   float64
#  20  USO_Open         3386 non-null   float64
#  21  USO_High         3386 non-null   float64
#  22  USO_Low          3386 non-null   float64
#  23  USO_Close        3386 non-null   float64
#  24  USO_Volume       3386 non-null   float64
#  25  CL_F_Open        3386 non-null   float64
#  26  CL_F_High        3386 non-null   float64
#  27  CL_F_Low         3386 non-null   float64
#  28  CL_F_Close       3386 non-null   float64
#  29  PL_F_Open        3386 non-null   float64
#  30  PL_F_High        3386 non-null   float64
#  31  PL_F_Low         3386 non-null   float64
#  32  PL_F_Close       3386 non-null   float64
#  33  TNX_Open         3386 non-null   float64
#  34  TNX_High         3386 non-null   float64
#  35  TNX_Low          3386 non-null   float64
#  36  TNX_Close        3386 non-null   float64
#  37  GVZ_Open         3386 non-null   float64
#  38  GVZ_High         3386 non-null   float64
#  39  GVZ_Low          3386 non-null   float64
#  40  GVZ_Close        3386 non-null   float64
#  41  MOVE_Open        3386 non-null   float64
#  42  MOVE_High        3386 non-null   float64
#  43  MOVE_Low         3386 non-null   float64
#  44  MOVE_Close       3386 non-null   float64
#  45  GC_F_Open        3386 non-null   float64
#  46  GC_F_High        3386 non-null   float64
#  47  GC_F_Low         3386 non-null   float64
#  48  GC_F_Close       3386 non-null   float64
#  49  EGO_Open         3386 non-null   float64
#  50  EGO_High         3386 non-null   float64
#  51  EGO_Low          3386 non-null   float64
#  52  EGO_Close        3386 non-null   float64
#  53  EGO_Volume       3386 non-null   float64
#  54  SI_F_Open        3386 non-null   float64
#  55  SI_F_High        3386 non-null   float64
#  56  SI_F_Low         3386 non-null   float64
#  57  SI_F_Close       3386 non-null   float64
#  58  DJI_Open         3386 non-null   float64
#  59  DJI_High         3386 non-null   float64
#  60  DJI_Low          3386 non-null   float64
#  61  DJI_Close        3386 non-null   float64
#  62  GDX_Open         3386 non-null   float64
#  63  GDX_High         3386 non-null   float64
#  64  GDX_Low          3386 non-null   float64
#  65  GDX_Close        3386 non-null   float64
#  66  GDX_Volume       3386 non-null   float64
#  67  GSPC_Open        3386 non-null   float64
#  68  GSPC_High        3386 non-null   float64
#  69  GSPC_Low         3386 non-null   float64
#  70  GSPC_Close       3386 non-null   float64
#  71  EURUSD_X_Open    3386 non-null   float64
#  72  EURUSD_X_High    3386 non-null   float64
#  73  EURUSD_X_Low     3386 non-null   float64
#  74  EURUSD_X_Close   3386 non-null   float64
#  75  close_diff1      3386 non-null   float64
#  76  target_tomorrow  3386 non-null   float64
#  77  rolling_mean7    3386 non-null   float64
#  78  vol_7            3386 non-null   float64
#  79  vol_15           3386 non-null   float64
#  80  vol_30           3386 non-null   float64
#  81  day_num          3386 non-null   int64
#  82  month            3386 non-null   int64
#  83  year             3386 non-null   int64
#  84  momentum_7       3386 non-null   float64
#  85  momentum_15      3386 non-null   float64
#  86  momentum_30      3386 non-null   float64
# dtypes: float64(84), int64(3)
# memory usage: 2.3+ MB

# %%
df.head()
# Out:
#              VIX_Open  VIX_High    VIX_Low  VIX_Close  DX-Y.NYB_Open  \
# Date
# 2012-01-26  17.959999     19.17  16.799999  18.570000      79.489998
# 2012-01-27  19.160000     19.16  18.260000  18.530001      79.449997
# 2012-01-30  20.330000     20.33  19.379999  19.400000      78.900002
# 2012-01-31  19.070000     19.84  18.129999  19.440001      79.099998
# 2012-02-01  18.680000     18.82  17.990000  18.549999      79.309998
#
#             DX-Y.NYB_High  DX-Y.NYB_Low  DX-Y.NYB_Close   PA_F_Open  \
# Date
# 2012-01-26      79.540001     79.059998       79.410004  693.900024
# 2012-01-27      79.540001     78.769997       78.900002  689.599976
# 2012-01-30      79.449997     78.769997       79.160004  688.099976
# 2012-01-31      79.480003     78.739998       79.279999  685.950012
# 2012-02-01      79.570000     78.620003       78.919998  696.299988
#
#              PA_F_High  ...  rolling_mean7     vol_7    vol_15    vol_30  \
# Date                    ...
# 2012-01-26  693.900024  ...    1677.942854  0.010289  0.008987  0.009661
# 2012-01-27  689.599976  ...    1688.271432  0.010258  0.008823  0.009467
# 2012-01-30  688.099976  ...    1699.257150  0.009878  0.008515  0.009463
# 2012-01-31  685.950012  ...    1709.842878  0.009927  0.008087  0.009257
# 2012-02-01  696.299988  ...    1719.714303  0.009877  0.008089  0.009226
#
#             day_num  month  year  momentum_7  momentum_15  momentum_30
# Date
# 2012-01-26       26      1  2012    0.042956     0.066012     0.096342
# 2012-01-27       27      1  2012    0.043567     0.071592     0.085360
# 2012-01-30       30      1  2012    0.046491     0.076827     0.085675
# 2012-01-31       31      1  2012    0.044539     0.065481     0.075638
# 2012-02-01        1      2  2012    0.041180     0.065825     0.083876
#
# [5 rows x 87 columns]

# %%
df = df.drop(columns=['close_diff1','rolling_mean7', 'vol_7', 'vol_15',
       'vol_30', 'day_num', 'month', 'year', 'momentum_7', 'momentum_15',
       'momentum_30', 'target_tomorrow'])

# %%
# --- 2. Lags du prix ---
df["GC_close_lag1"] = df["GC_F_Close"].shift(1)
df["GC_close_lag2"] = df["GC_F_Close"].shift(2)

# --- 3. Range intraday ---
df["GC_range"] = df["GC_F_High"] - df["GC_F_Low"]
df["GC_range_pct"] = (df["GC_F_High"] - df["GC_F_Low"]) / df["GC_F_Close"]

# --- 4. True Range (volatilité intraday robuste) ---
df["GC_true_range"] = np.maximum(df["GC_F_High"] - df["GC_F_Low"],
                                 np.maximum(abs(df["GC_F_High"] - df["GC_F_Close"].shift(1)),
                                            abs(df["GC_F_Low"] - df["GC_F_Close"].shift(1))))

# --- 5. Position du close dans la journée ---
df["GC_close_position"] = (df["GC_F_Close"] - df["GC_F_Low"]) / (df["GC_F_High"] - df["GC_F_Low"])

# --- 6. Intraday return (Open → Close) ---
df["GC_intraday_return"] = (df["GC_F_Close"] - df["GC_F_Open"]) / df["GC_F_Open"]

# %%
# ============================
# 1. LISTE DES COLONNES
# ============================

price_cols = [
    'VIX_Close', 'DX-Y.NYB_Close', 'PA_F_Close', 'BZ_F_Close', 'OVX_Close',
    'USO_Close', 'CL_F_Close', 'PL_F_Close', 'TNX_Close', 'GVZ_Close',
    'MOVE_Close', 'GC_F_Close', 'EGO_Close', 'SI_F_Close', 'DJI_Close',
    'GDX_Close', 'GSPC_Close', 'EURUSD_X_Close'
]

volume_cols = ['USO_Volume', 'EGO_Volume', 'GDX_Volume']


# ============================
# 2. RETURNS
# ============================

for col in price_cols:
    df[col + "_ret"] = df[col].pct_change()


# ============================
# 3. LAGS (mémoire temporelle)
# ============================

lags = [1, 2, 3, 5]

for col in price_cols:
    for lag in lags:
        df[f"{col}_ret_lag{lag}"] = df[col + "_ret"].shift(lag)


# ============================
# 4. ROLLING STATS (vol, momentum, skew)
# ============================

windows = [5, 20, 60]

for col in price_cols:
    ret = df[col + "_ret"]
    for w in windows:
        df[f"{col}_vol_{w}"] = ret.rolling(w).std()
        df[f"{col}_mom_{w}"] = ret.rolling(w).mean()
        df[f"{col}_skew_{w}"] = ret.rolling(w).skew()
        df[f"{col}_kurt_{w}"] = ret.rolling(w).kurt()


# ============================
# 5. SPREADS & RATIOS
# ============================

df["gold_silver"] = df["GC_F_Close"] / df["SI_F_Close"]
df["gold_oil"] = df["GC_F_Close"] / df["CL_F_Close"]
df["gold_dxy"] = df["GC_F_Close"] * df["DX-Y.NYB_Close"]
df["gold_spx"] = df["GC_F_Close"] / df["GSPC_Close"]
df["gold_vix"] = df["GC_F_Close"] / df["VIX_Close"]
df["silver_oil"] = df["SI_F_Close"] / df["CL_F_Close"]
df["usd_spread"] = df["DX-Y.NYB_Close"] / df["EURUSD_X_Close"]
df["gold_rate"] = df["GC_F_Close"] / df["TNX_Close"]
df["spx_vix"] = df["GSPC_Close"] * df["VIX_Close"]

spread_cols = [
    "gold_silver", "gold_oil", "gold_dxy", "gold_spx", "gold_vix",
    "silver_oil", "usd_spread", "gold_rate", "spx_vix"
]

# returns + lags + rolling sur spreads
for col in spread_cols:
    df[col + "_ret"] = df[col].pct_change()
    for lag in lags:
        df[f"{col}_ret_lag{lag}"] = df[col + "_ret"].shift(lag)
    for w in windows:
        df[f"{col}_vol_{w}"] = df[col + "_ret"].rolling(w).std()
        df[f"{col}_mom_{w}"] = df[col + "_ret"].rolling(w).mean()


# ============================
# 6. VOLUMES
# ============================

for col in volume_cols:
    df[col + "_ret"] = df[col].pct_change()
    df[col + "_zscore"] = (df[col] - df[col].rolling(20).mean()) / df[col].rolling(20).std()
    for w in windows:
        df[f"{col}_mom_{w}"] = df[col + "_ret"].rolling(w).mean()


# ============================
# 7. CROSS-ASSET INTERACTIONS
# ============================

df["gold_vix_interact"] = df["GC_F_Close_ret"] * df["VIX_Close_ret"]
df["gold_dxy_interact"] = df["GC_F_Close_ret"] * df["DX-Y.NYB_Close_ret"]
df["gold_oil_interact"] = df["GC_F_Close_ret"] * df["CL_F_Close_ret"]
df["gold_spx_interact"] = df["GC_F_Close_ret"] * df["GSPC_Close_ret"]


# ============================
# 8. FEATURES SPÉCIFIQUES AU GOLD
# ============================

df["gold_vol_20"] = df["GC_F_Close_ret"].rolling(20).std()
df["gold_mom_20"] = df["GC_F_Close_ret"].rolling(20).mean()
df["gold_skew_20"] = df["GC_F_Close_ret"].rolling(20).skew()
df["gold_kurt_20"] = df["GC_F_Close_ret"].rolling(20).kurt()

# %% [markdown]
# # Création de la target return pour contrer la problématique de prédiction de valeurs jamais vues dans le train

# %%
#df["target_return"] = df["GC_F_Close"].pct_change().shift(-1)

# %%
df["target_return"] = df["GC_F_Close"].pct_change(1).shift(-1)
# Out:
# /tmp/ipykernel_2469/1284045041.py:1: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`

# %%
df = df.dropna()

# %%
"""df = df.drop(columns=[
    'VIX_Close', 'DX-Y.NYB_Close', 'PA_F_Close', 'BZ_F_Close', 'OVX_Close',
    'USO_Close', 'CL_F_Close', 'PL_F_Close', 'TNX_Close', 'GVZ_Close',
    'MOVE_Close', 'EGO_Close', 'SI_F_Close', 'DJI_Close',
    'GDX_Close', 'GSPC_Close', 'EURUSD_X_Close','USO_Volume', 'EGO_Volume', 'GDX_Volume'
])"""

# %%
df.columns
# Out:
# Index(['VIX_Open', 'VIX_High', 'VIX_Low', 'VIX_Close', 'DX-Y.NYB_Open',
#        'DX-Y.NYB_High', 'DX-Y.NYB_Low', 'DX-Y.NYB_Close', 'PA_F_Open',
#        'PA_F_High',
#        ...
#        'GDX_Volume_mom_60', 'gold_vix_interact', 'gold_dxy_interact',
#        'gold_oil_interact', 'gold_spx_interact', 'gold_vol_20', 'gold_mom_20',
#        'gold_skew_20', 'gold_kurt_20', 'target_return'],
#       dtype='object', length=520)

# %%
df = drop_ohl_columns(df)

# %% [markdown]
# # Split chronologique

# %%
# 1. On récupère les index
n = len(df)
n
# Out:
# 3164

# %%
train_end = int(n * 0.80)
val_end   = int(n * 0.95)

# 2. Split chronologique
train_df = df.iloc[:train_end]
val_df   = df.iloc[train_end:val_end]
test_df  = df.iloc[val_end:]

# %%
X_train = train_df.drop(columns=["target_return"])
y_train = train_df["target_return"]

X_val = val_df.drop(columns=["target_return"])
y_val = val_df["target_return"]

X_test = test_df.drop(columns=["target_return"])
y_test = test_df["target_return"]

# %% [markdown]
# # Instanciation du modèle

# %%
early_stop = EarlyStopping(rounds=50, save_best=True)

model = XGBRegressor(
    n_estimators=600,
    learning_rate=0.02,
    max_depth=4,
    subsample=0.8,
    colsample_bytree=0.8,
    reg_alpha=1.0,
    reg_lambda=2.0,
    min_child_weight=3,
    objective="reg:squarederror",
    tree_method="hist",
    callbacks = [early_stop]
)

model.fit(
    X_train, y_train,
    eval_set=[(X_train,y_train),(X_val, y_val)],
    verbose=True,
)
# Out:
# [0]	validation_0-rmse:0.01017	validation_1-rmse:0.00921
# [1]	validation_0-rmse:0.01017	validation_1-rmse:0.00921
# [2]	validation_0-rmse:0.01017	validation_1-rmse:0.00921
# [3]	validation_0-rmse:0.01017	validation_1-rmse:0.00921
# [4]	validation_0-rmse:0.01017	validation_1-rmse:0.00921
# [5]	validation_0-rmse:0.01017	validation_1-rmse:0.00921
# [6]	validation_0-rmse:0.01017	validation_1-rmse:0.00921
# [7]	validation_0-rmse:0.01016	validation_1-rmse:0.00921
# [8]	validation_0-rmse:0.01016	validation_1-rmse:0.00921
# [9]	validation_0-rmse:0.01016	validation_1-rmse:0.00921
# [10]	validation_0-rmse:0.01016	validation_1-rmse:0.00921
# [11]	validation_0-rmse:0.01016	validation_1-rmse:0.00921
# [12]	validation_0-rmse:0.01016	validation_1-rmse:0.00921
# [13]	validation_0-rmse:0.01016	validation_1-rmse:0.00921
# [14]	validation_0-rmse:0.01016	validation_1-rmse:0.00921
# [15]	validation_0-rmse:0.01016	validation_1-rmse:0.00921
# [16]	validation_0-rmse:0.01016	validation_1-rmse:0.00921
# [17]	validation_0-rmse:0.01015	validation_1-rmse:0.00921
# [18]	validation_0-rmse:0.01015	validation_1-rmse:0.00921
# [19]	validation_0-rmse:0.01015	validation_1-rmse:0.00920
# [20]	validation_0-rmse:0.01015	validation_1-rmse:0.00920
# [21]	validation_0-rmse:0.01015	validation_1-rmse:0.00920
# [22]	validation_0-rmse:0.01015	validation_1-rmse:0.00920
# [23]	validation_0-rmse:0.01015	validation_1-rmse:0.00920
# [24]	validation_0-rmse:0.01015	validation_1-rmse:0.00920
# [25]	validation_0-rmse:0.01015	validation_1-rmse:0.00920
# [26]	validation_0-rmse:0.01015	validation_1-rmse:0.00920
# [27]	validation_0-rmse:0.01015	validation_1-rmse:0.00920
# [28]	validation_0-rmse:0.01014	validation_1-rmse:0.00920
# [29]	validation_0-rmse:0.01014	validation_1-rmse:0.00920
# [30]	validation_0-rmse:0.01014	validation_1-rmse:0.00920
# [31]	validation_0-rmse:0.01014	validation_1-rmse:0.00920
# [32]	validation_0-rmse:0.01014	validation_1-rmse:0.00920
# [33]	validation_0-rmse:0.01014	validation_1-rmse:0.00920
# [34]	validation_0-rmse:0.01014	validation_1-rmse:0.00920
# [35]	validation_0-rmse:0.01014	validation_1-rmse:0.00920
# [36]	validation_0-rmse:0.01014	validation_1-rmse:0.00920
# [37]	validation_0-rmse:0.01014	validation_1-rmse:0.00920
# [38]	validation_0-rmse:0.01014	validation_1-rmse:0.00920
# [39]	validation_0-rmse:0.01013	validation_1-rmse:0.00920
# [40]	validation_0-rmse:0.01013	validation_1-rmse:0.00920
# [41]	validation_0-rmse:0.01013	validation_1-rmse:0.00920
# [42]	validation_0-rmse:0.01013	validation_1-rmse:0.00920
# [43]	validation_0-rmse:0.01013	validation_1-rmse:0.00920
# [44]	validation_0-rmse:0.01013	validation_1-rmse:0.00920
# [45]	validation_0-rmse:0.01013	validation_1-rmse:0.00920
# [46]	validation_0-rmse:0.01013	validation_1-rmse:0.00920
# [47]	validation_0-rmse:0.01012	validation_1-rmse:0.00920
# [48]	validation_0-rmse:0.01012	validation_1-rmse:0.00920
# [49]	validation_0-rmse:0.01012	validation_1-rmse:0.00920
# [50]	validation_0-rmse:0.01012	validation_1-rmse:0.00920
# [51]	validation_0-rmse:0.01012	validation_1-rmse:0.00920
# [52]	validation_0-rmse:0.01012	validation_1-rmse:0.00920
# [53]	validation_0-rmse:0.01012	validation_1-rmse:0.00920
# [54]	validation_0-rmse:0.01012	validation_1-rmse:0.00920
# [55]	validation_0-rmse:0.01012	validation_1-rmse:0.00920
# [56]	validation_0-rmse:0.01012	validation_1-rmse:0.00920
# [57]	validation_0-rmse:0.01012	validation_1-rmse:0.00920
# [58]	validation_0-rmse:0.01012	validation_1-rmse:0.00920
# [59]	validation_0-rmse:0.01012	validation_1-rmse:0.00920
# [60]	validation_0-rmse:0.01012	validation_1-rmse:0.00920
# [61]	validation_0-rmse:0.01012	validation_1-rmse:0.00920
# [62]	validation_0-rmse:0.01012	validation_1-rmse:0.00920
# [63]	validation_0-rmse:0.01012	validation_1-rmse:0.00920
# [64]	validation_0-rmse:0.01012	validation_1-rmse:0.00920
# [65]	validation_0-rmse:0.01012	validation_1-rmse:0.00920
# [66]	validation_0-rmse:0.01012	validation_1-rmse:0.00920
# [67]	validation_0-rmse:0.01012	validation_1-rmse:0.00920
# [68]	validation_0-rmse:0.01012	validation_1-rmse:0.00920
# [69]	validation_0-rmse:0.01012	validation_1-rmse:0.00920
# [70]	validation_0-rmse:0.01012	validation_1-rmse:0.00920
# [71]	validation_0-rmse:0.01012	validation_1-rmse:0.00920
# [72]	validation_0-rmse:0.01012	validation_1-rmse:0.00920
# [73]	validation_0-rmse:0.01012	validation_1-rmse:0.00920
# [74]	validation_0-rmse:0.01012	validation_1-rmse:0.00920
# [75]	validation_0-rmse:0.01012	validation_1-rmse:0.00920
# [76]	validation_0-rmse:0.01012	validation_1-rmse:0.00920
# [77]	validation_0-rmse:0.01012	validation_1-rmse:0.00920
# [78]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [79]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [80]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [81]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [82]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [83]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [84]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [85]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [86]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [87]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [88]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [89]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [90]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [91]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [92]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [93]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [94]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [95]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [96]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [97]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [98]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [99]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [100]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [101]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [102]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [103]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [104]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [105]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [106]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [107]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [108]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [109]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [110]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [111]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [112]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [113]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [114]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [115]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [116]	validation_0-rmse:0.01011	validation_1-rmse:0.00920
# [117]	validation_0-rmse:0.01011	validation_1-rmse:0.00919
# [118]	validation_0-rmse:0.01010	validation_1-rmse:0.00919
# [119]	validation_0-rmse:0.01010	validation_1-rmse:0.00919
# [120]	validation_0-rmse:0.01010	validation_1-rmse:0.00919
# [121]	validation_0-rmse:0.01010	validation_1-rmse:0.00919
# [122]	validation_0-rmse:0.01010	validation_1-rmse:0.00919
# [123]	validation_0-rmse:0.01010	validation_1-rmse:0.00919
# [124]	validation_0-rmse:0.01010	validation_1-rmse:0.00919
# [125]	validation_0-rmse:0.01010	validation_1-rmse:0.00919
# [126]	validation_0-rmse:0.01010	validation_1-rmse:0.00919
# [127]	validation_0-rmse:0.01010	validation_1-rmse:0.00919
# [128]	validation_0-rmse:0.01010	validation_1-rmse:0.00919
# [129]	validation_0-rmse:0.01010	validation_1-rmse:0.00919
# [130]	validation_0-rmse:0.01010	validation_1-rmse:0.00919
# [131]	validation_0-rmse:0.01010	validation_1-rmse:0.00919
# [132]	validation_0-rmse:0.01010	validation_1-rmse:0.00919
# [133]	validation_0-rmse:0.01010	validation_1-rmse:0.00919
# [134]	validation_0-rmse:0.01010	validation_1-rmse:0.00919
# [135]	validation_0-rmse:0.01010	validation_1-rmse:0.00919
# [136]	validation_0-rmse:0.01010	validation_1-rmse:0.00919
# [137]	validation_0-rmse:0.01010	validation_1-rmse:0.00919
# [138]	validation_0-rmse:0.01010	validation_1-rmse:0.00919
# [139]	validation_0-rmse:0.01010	validation_1-rmse:0.00919
# [140]	validation_0-rmse:0.01010	validation_1-rmse:0.00919
# [141]	validation_0-rmse:0.01010	validation_1-rmse:0.00919
# [142]	validation_0-rmse:0.01010	validation_1-rmse:0.00919
# [143]	validation_0-rmse:0.01009	validation_1-rmse:0.00919
# [144]	validation_0-rmse:0.01009	validation_1-rmse:0.00919
# [145]	validation_0-rmse:0.01009	validation_1-rmse:0.00919
# [146]	validation_0-rmse:0.01009	validation_1-rmse:0.00919
# [147]	validation_0-rmse:0.01009	validation_1-rmse:0.00919
# [148]	validation_0-rmse:0.01009	validation_1-rmse:0.00919
# [149]	validation_0-rmse:0.01009	validation_1-rmse:0.00919
# [150]	validation_0-rmse:0.01009	validation_1-rmse:0.00919
# [151]	validation_0-rmse:0.01009	validation_1-rmse:0.00919
# [152]	validation_0-rmse:0.01009	validation_1-rmse:0.00919
# [153]	validation_0-rmse:0.01009	validation_1-rmse:0.00919
# [154]	validation_0-rmse:0.01009	validation_1-rmse:0.00919
# [155]	validation_0-rmse:0.01009	validation_1-rmse:0.00919
# [156]	validation_0-rmse:0.01009	validation_1-rmse:0.00919
# [157]	validation_0-rmse:0.01009	validation_1-rmse:0.00919
# [158]	validation_0-rmse:0.01009	validation_1-rmse:0.00919
# [159]	validation_0-rmse:0.01009	validation_1-rmse:0.00919
# [160]	validation_0-rmse:0.01009	validation_1-rmse:0.00919
# [161]	validation_0-rmse:0.01009	validation_1-rmse:0.00919
# [162]	validation_0-rmse:0.01009	validation_1-rmse:0.00919
# [163]	validation_0-rmse:0.01009	validation_1-rmse:0.00919
# [164]	validation_0-rmse:0.01009	validation_1-rmse:0.00919
# [165]	validation_0-rmse:0.01009	validation_1-rmse:0.00919
# [166]	validation_0-rmse:0.01009	validation_1-rmse:0.00919
# [167]	validation_0-rmse:0.01009	validation_1-rmse:0.00919
# [168]	validation_0-rmse:0.01009	validation_1-rmse:0.00919
# [169]	validation_0-rmse:0.01009	validation_1-rmse:0.00919
# [170]	validation_0-rmse:0.01009	validation_1-rmse:0.00919
# [171]	validation_0-rmse:0.01009	validation_1-rmse:0.00919
# [172]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [173]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [174]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [175]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [176]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [177]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [178]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [179]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [180]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [181]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [182]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [183]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [184]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [185]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [186]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [187]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [188]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [189]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [190]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [191]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [192]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [193]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [194]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [195]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [196]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [197]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [198]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [199]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [200]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [201]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [202]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [203]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [204]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [205]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [206]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [207]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [208]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [209]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [210]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [211]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [212]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [213]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [214]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [215]	validation_0-rmse:0.01008	validation_1-rmse:0.00919
# [216]	validation_0-rmse:0.01008	validation_1-rmse:0.00918
# [217]	validation_0-rmse:0.01008	validation_1-rmse:0.00918
# [218]	validation_0-rmse:0.01008	validation_1-rmse:0.00918
# [219]	validation_0-rmse:0.01008	validation_1-rmse:0.00918
# [220]	validation_0-rmse:0.01008	validation_1-rmse:0.00918
# [221]	validation_0-rmse:0.01008	validation_1-rmse:0.00918
# [222]	validation_0-rmse:0.01008	validation_1-rmse:0.00918
# [223]	validation_0-rmse:0.01008	validation_1-rmse:0.00918
# [224]	validation_0-rmse:0.01008	validation_1-rmse:0.00918
# [225]	validation_0-rmse:0.01008	validation_1-rmse:0.00918
# [226]	validation_0-rmse:0.01008	validation_1-rmse:0.00918
# [227]	validation_0-rmse:0.01008	validation_1-rmse:0.00918
# [228]	validation_0-rmse:0.01008	validation_1-rmse:0.00918
# [229]	validation_0-rmse:0.01008	validation_1-rmse:0.00918
# [230]	validation_0-rmse:0.01008	validation_1-rmse:0.00918
# [231]	validation_0-rmse:0.01008	validation_1-rmse:0.00918
# [232]	validation_0-rmse:0.01008	validation_1-rmse:0.00918
# [233]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [234]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [235]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [236]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [237]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [238]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [239]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [240]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [241]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [242]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [243]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [244]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [245]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [246]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [247]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [248]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [249]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [250]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [251]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [252]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [253]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [254]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [255]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [256]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [257]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [258]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [259]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [260]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [261]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [262]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [263]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [264]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [265]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [266]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [267]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [268]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [269]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [270]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [271]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [272]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [273]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [274]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [275]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [276]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [277]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [278]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [279]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [280]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [281]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [282]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [283]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [284]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [285]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [286]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [287]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [288]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [289]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [290]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [291]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [292]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# [293]	validation_0-rmse:0.01007	validation_1-rmse:0.00918
# XGBRegressor(base_score=None, booster=None,
#              callbacks=[<xgboost.callback.EarlyStopping object at 0x78a7bdf66170>],
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.02, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#              max_leaves=None, min_child_weight=3, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=600,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred_test = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

rmse_test = np.sqrt(mean_squared_error(y_test, y_pred_test))
print("Test RMSE:", rmse_test)
# Out:
# Test RMSE: 0.013873410907153667

# %%
mae_test = mean_absolute_error(y_test, y_pred_test)
print("Test MAE:", mae_test)
# Out:
# Test MAE: 0.01025367046204808

# %% [markdown]
# # Suppressin des returns

# %%
pred_price = X_test["GC_F_Close"] * (1 + y_pred_test)
true_price = X_test["GC_F_Close"] * (1 + y_test)

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=true_price.index,
    y=true_price,
    mode='lines',
    name='True Price'
))

fig.add_trace(go.Scatter(
    x=pred_price.index,
    y=pred_price,
    mode='lines',
    name='Predicted Price'
))

fig.update_layout(
    title="True vs Predicted Gold Price (Test Set)",
    xaxis_title="Date",
    yaxis_title="Price",
    template="plotly_white"
)

fig.show()

# %%
import plotly.express as px

fig = px.scatter(
    x=y_test,
    y=y_pred_test,
    labels={'x': 'True Return', 'y': 'Predicted Return'},
    title="True vs Predicted Returns (Test Set)"
)
fig.show()

# %%
y_test.describe()
# Out:
# count    159.000000
# mean       0.001624
# std        0.013889
# min       -0.057352
# 25%       -0.005446
# 50%        0.002223
# 75%        0.009142
# max        0.040947
# Name: target_return, dtype: float64

# %%
y_pred_test.mean(), y_pred_test.std()
# Out:
# (0.0001764357, 0.00021668516)

# %%
df.columns
# Out:
# Index(['VIX_Close', 'DX-Y.NYB_Close', 'PA_F_Close', 'BZ_F_Close', 'OVX_Close',
#        'USO_Close', 'USO_Volume', 'CL_F_Close', 'PL_F_Close', 'TNX_Close',
#        ...
#        'GDX_Volume_mom_60', 'gold_vix_interact', 'gold_dxy_interact',
#        'gold_oil_interact', 'gold_spx_interact', 'gold_vol_20', 'gold_mom_20',
#        'gold_skew_20', 'gold_kurt_20', 'target_return'],
#       dtype='object', length=466)

# %%
y_pred_test = pd.Series(y_pred_test, index=y_test.index)

# %%
y_test.corr(y_pred_test)
# Out:
# 0.22646107970623763

# %%
residuals = y_test - y_pred_test
residuals
# Out:
# Date
# 2025-04-11   -0.005573
# 2025-04-14    0.003705
# 2025-04-15    0.033321
# 2025-04-16   -0.005714
# 2025-04-17    0.027540
#                 ...
# 2025-12-03    0.002860
# 2025-12-04    0.000228
# 2025-12-05   -0.006217
# 2025-12-08    0.004503
# 2025-12-09   -0.002689
# Length: 159, dtype: float64

# %%
direction_acc = (np.sign(y_pred_test) == np.sign(y_test)).mean()
direction_acc
# Out:
# 0.5849056603773585

# %%
mean_absolute_error(true_price,pred_price)
# Out:
# 37.11350791443653

# %%
pred_price
# Out:
# Date
# 2025-04-11    3222.755767
# 2025-04-14    3206.825635
# 2025-04-15    3219.348402
# 2025-04-16    3327.708487
# 2025-04-17    3309.677738
#                  ...
# 2025-12-03    4199.790889
# 2025-12-04    4211.938882
# 2025-12-05    4213.393079
# 2025-12-08    4187.843105
# 2025-12-09    4207.710171
# Name: GC_F_Close, Length: 159, dtype: float64

# %%
true_price
# Out:
# Date
# 2025-04-11    3204.800049
# 2025-04-14    3218.699951
# 2025-04-15    3326.600098
# 2025-04-16    3308.699951
# 2025-04-17    3400.800049
#                  ...
# 2025-12-03    4211.799805
# 2025-12-04    4212.899902
# 2025-12-05    4187.200195
# 2025-12-08    4206.700195
# 2025-12-09    4196.399902
# Length: 159, dtype: float64
